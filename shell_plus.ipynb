# %%
import os
import django
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "django_model_populator.settings")
django.setup()

# %%
from django.apps import apps
from books.models import *
from asgiref.sync import sync_to_async
from fake_filler.fakers import generate_fake_data_for_model

# %%
await sync_to_async(generate_fake_data_for_model)("auth", "user")
# Out:
# /Users/ace/projects/ops/django_model_populator/venv/lib/python3.13/site-packages/django/db/models/fields/__init__.py:1671: RuntimeWarning: DateTimeField User.last_login received a naive datetime (1984-05-12 22:44:19.437213) while time zone support is active.
#   warnings.warn(
# ---------------------------------------------------------------------------
# UniquenessException                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 await sync_to_async(generate_fake_data_for_model)("auth", "user")
#
# File ~/projects/ops/django_model_populator/venv/lib/python3.13/site-packages/asgiref/sync.py:439, in SyncToAsync.__call__(self, *args, **kwargs)
#     437 ret: _R
#     438 try:
# --> 439     ret = await asyncio.shield(exec_coro)
#     440 except asyncio.CancelledError:
#     441     cancel_parent = True
#
# ...
